# %%
import pandas as pd

# %%
feature = pd.read_csv("taylorswift-Features.csv")
track = pd.read_csv("taylorswift-Tracks.csv")

# %%
feature
# Out:
#      Unnamed: 0                album_id                        album_name  \
# 0             0  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# 1             1  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# 2             2  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# 3             3  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# 4             4  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# ..          ...                     ...                               ...
# 241         241  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
# 242         242  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
# 243         243  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
# 244         244  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
# 245         245  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
#
#                          id                                     track_name  \
# ...

# %%
track
# Out:
#      Unnamed: 0                album_id                        album_name  \
# 0             0  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# 1             1  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# 2             2  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# 3             3  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# 4             4  1o59UpKw81iHR0HPiSkJR0  1989 (Taylor's Version) [Deluxe]
# ..          ...                     ...                               ...
# 241         241  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
# 242         242  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
# 243         243  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
# 244         244  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
# 245         245  5eyZZoQEFQWRHkV2xgAeBw                      Taylor Swift
#
#                          id                                           name  \
# ...
